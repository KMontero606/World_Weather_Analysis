# %% [markdown]
# # Deliverable 1: Retrieve Weather Data

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from citipy import citipy
from config import weather_api_key
import time
from datetime import datetime

# 3. Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# 4. Get the nearest city using the citipy module.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 754

# %%
# 5. Perform an API call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6. Retrieve the following information from the API call:
#Latitude and longitude
#Maximum temperature
#Percent humidity
#Percent cloudiness
#Wind speed
#Weather description (for example, clouds, fog, light rain, clear sky)
# Create an empty list to hold the weather data.
city_data = []

# Print the beginnign of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_country = city_weather["sys"]["country"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather['weather'][0]['description']
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bud
# Processing Record 2 of Set 1 | bouca
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | hegang
# Processing Record 6 of Set 1 | georgetown
# Processing Record 7 of Set 1 | cherskiy
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | padang
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | luau
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | palu
# Processing Record 15 of Set 1 | viesca
# Processing Record 16 of Set 1 | okahandja
# Processing Record 17 of Set 1 | pisco
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | provideniya
# Processing Record 20 of Set 1 | torbay
# Processing Record 21 of Set 1 | sistranda
# Processing Record 22 of Set 1 | susanville
# Processing Record 23 of Set 1 | iracoubo
# Processing Record 24 of Set 1 | praya
# Processing Record 25 of Set 1 | yulara
# Processing Record 26 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 27 of Set 1 | matara
# Processing Record 28 of Set 1 | ejura
# Processing Record 29 of Set 1 | laguna
# Processing Record 30 of Set 1 | hamina
# Processing Record 31 of Set 1 | marzuq
# Processing Record 32 of Set 1 | saint-philippe
# Processing Record 33 of Set 1 | jamestown
# Processing Record 34 of Set 1 | ulkan
# Processing Record 35 of Set 1 | half moon bay
# Processing Record 36 of Set 1 | saint anthony
# Processing Record 37 of Set 1 | dikson
# Processing Record 38 of Set 1 | arraial do cabo
# Processing Record 39 of Set 1 | shimoda
# Processing Record 40 of Set 1 | bethel
# Processing Record 41 of Set 1 | tasiilaq
# Processing Record 42 of Set 1 | chokurdakh
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | port elizabeth
# Processing Record 45 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 46 of Set 1 | albany
# Processing Record 47 of Set 1 | macuspana
# Processing Record 48 of Set 1 | petlawad
# Processing Record 49 of Set 1 | norman wells
# Processing Record 50 of Set 1 | saint-augustin
# Processing Record 1 of Set 2 | cayenne
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | buala
# Processing Record 4 of Set 2 | ondjiva
# Processing Record 5 of Set 2 | los llanos de aridane
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | cidreira
# Processing Record 8 of Set 2 | atuona
# Processing Record 9 of Set 2 | ushuaia
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | waipawa
# Processing Record 12 of Set 2 | demba
# Processing Record 13 of Set 2 | jieshi
# Processing Record 14 of Set 2 | sovetskiy
# Processing Record 15 of Set 2 | sao filipe
# Processing Record 16 of Set 2 | viligili
# City not found. Skipping...
# Processing Record 17 of Set 2 | teya
# Processing Record 18 of Set 2 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 2 | husavik
# Processing Record 20 of Set 2 | nizhniy kuranakh
# Processing Record 21 of Set 2 | onguday
# Processing Record 22 of Set 2 | new norfolk
# Processing Record 23 of Set 2 | nome
# Processing Record 24 of Set 2 | abu ghosh
# Processing Record 25 of Set 2 | cap malheureux
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | toba
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | blackwater
# Processing Record 30 of Set 2 | teshie
# Processing Record 31 of Set 2 | kwakoa
# Processing Record 32 of Set 2 | paamiut
# Processing Record 33 of Set 2 | hobart
# Processing Record 34 of Set 2 | teguldet
# Processing Record 35 of Set 2 | kirakira
# Processing Record 36 of Set 2 | lindi
# Processing Record 37 of Set 2 | broken hill
# Processing Record 38 of Set 2 | flinders
# Processing Record 39 of Set 2 | luderitz
# Processing Record 40 of Set 2 | kottayam
# Processing Record 41 of Set 2 | astrea
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | khuzhir
# Processing Record 45 of Set 2 | diu
# Processing Record 46 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 47 of Set 2 | constitucion
# Processing Record 48 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 49 of Set 2 | surop
# City not found. Skipping...
# Processing Record 50 of Set 2 | rikitea
# Processing Record 1 of Set 3 | faya
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | muros
# Processing Record 4 of Set 3 | kasongo-lunda
# Processing Record 5 of Set 3 | bambous virieux
# Processing Record 6 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | souillac
# Processing Record 9 of Set 3 | bluff
# Processing Record 10 of Set 3 | marystown
# Processing Record 11 of Set 3 | suntar
# Processing Record 12 of Set 3 | nikolskoye
# Processing Record 13 of Set 3 | lagos
# Processing Record 14 of Set 3 | lieksa
# Processing Record 15 of Set 3 | shache
# Processing Record 16 of Set 3 | khatanga
# Processing Record 17 of Set 3 | yellowknife
# Processing Record 18 of Set 3 | san patricio
# Processing Record 19 of Set 3 | prince rupert
# Processing Record 20 of Set 3 | dossor
# Processing Record 21 of Set 3 | ilulissat
# Processing Record 22 of Set 3 | kruisfontein
# Processing Record 23 of Set 3 | colquechaca
# Processing Record 24 of Set 3 | oussouye
# Processing Record 25 of Set 3 | port hardy
# Processing Record 26 of Set 3 | bredasdorp
# Processing Record 27 of Set 3 | lobito
# Processing Record 28 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | vila velha
# Processing Record 32 of Set 3 | ribeira grande
# Processing Record 33 of Set 3 | wulanhaote
# City not found. Skipping...
# Processing Record 34 of Set 3 | mahebourg
# Processing Record 35 of Set 3 | maceio
# Processing Record 36 of Set 3 | qaanaaq
# Processing Record 37 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 3 | zhezkazgan
# Processing Record 39 of Set 3 | port augusta
# Processing Record 40 of Set 3 | parnamirim
# Processing Record 41 of Set 3 | hithadhoo
# Processing Record 42 of Set 3 | makinsk
# Processing Record 43 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 3 | ust-shonosha
# Processing Record 45 of Set 3 | kapaa
# Processing Record 46 of Set 3 | tirthahalli
# Processing Record 47 of Set 3 | saldanha
# Processing Record 48 of Set 3 | upernavik
# Processing Record 49 of Set 3 | cape town
# Processing Record 50 of Set 3 | vanimo
# Processing Record 1 of Set 4 | kavieng
# Processing Record 2 of Set 4 | salgueiro
# Processing Record 3 of Set 4 | tiznit
# Processing Record 4 of Set 4 | tyler
# Processing Record 5 of Set 4 | mackay
# Processing Record 6 of Set 4 | kodiak
# Processing Record 7 of Set 4 | vaini
# Processing Record 8 of Set 4 | sao miguel do araguaia
# Processing Record 9 of Set 4 | latung
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | hovd
# Processing Record 12 of Set 4 | pascagoula
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | gorodishche
# Processing Record 15 of Set 4 | murgab
# Processing Record 16 of Set 4 | kaitangata
# Processing Record 17 of Set 4 | ewa beach
# Processing Record 18 of Set 4 | ardmore
# Processing Record 19 of Set 4 | nanyuki
# Processing Record 20 of Set 4 | eregli
# Processing Record 21 of Set 4 | aklavik
# Processing Record 22 of Set 4 | mazyr
# Processing Record 23 of Set 4 | nuuk
# Processing Record 24 of Set 4 | homer
# Processing Record 25 of Set 4 | sungai padi
# Processing Record 26 of Set 4 | lata
# Processing Record 27 of Set 4 | salalah
# Processing Record 28 of Set 4 | isugod
# Processing Record 29 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 30 of Set 4 | felipe carrillo puerto
# Processing Record 31 of Set 4 | lixourion
# Processing Record 32 of Set 4 | mar del plata
# Processing Record 33 of Set 4 | raga
# Processing Record 34 of Set 4 | qasigiannguit
# Processing Record 35 of Set 4 | pimentel
# Processing Record 36 of Set 4 | hami
# Processing Record 37 of Set 4 | lewistown
# Processing Record 38 of Set 4 | makakilo city
# Processing Record 39 of Set 4 | klaksvik
# Processing Record 40 of Set 4 | honiara
# Processing Record 41 of Set 4 | ketchikan
# Processing Record 42 of Set 4 | beloha
# Processing Record 43 of Set 4 | agirish
# Processing Record 44 of Set 4 | warragul
# Processing Record 45 of Set 4 | katobu
# Processing Record 46 of Set 4 | ode
# Processing Record 47 of Set 4 | chuy
# Processing Record 48 of Set 4 | lagoa
# Processing Record 49 of Set 4 | saskylakh
# Processing Record 50 of Set 4 | faanui
# Processing Record 1 of Set 5 | palmer
# Processing Record 2 of Set 5 | mont-dore
# Processing Record 3 of Set 5 | nishihara
# Processing Record 4 of Set 5 | talkha
# Processing Record 5 of Set 5 | vao
# Processing Record 6 of Set 5 | fortuna
# Processing Record 7 of Set 5 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 5 | rundu
# Processing Record 9 of Set 5 | karacabey
# Processing Record 10 of Set 5 | vila do maio
# Processing Record 11 of Set 5 | havre-saint-pierre
# Processing Record 12 of Set 5 | eirunepe
# Processing Record 13 of Set 5 | mokhsogollokh
# Processing Record 14 of Set 5 | tura
# Processing Record 15 of Set 5 | orgun
# City not found. Skipping...
# Processing Record 16 of Set 5 | alofi
# Processing Record 17 of Set 5 | antofagasta
# Processing Record 18 of Set 5 | fort-shevchenko
# Processing Record 19 of Set 5 | miandrivazo
# Processing Record 20 of Set 5 | longyearbyen
# Processing Record 21 of Set 5 | la chaux-de-fonds
# Processing Record 22 of Set 5 | chapais
# Processing Record 23 of Set 5 | talnakh
# Processing Record 24 of Set 5 | flin flon
# Processing Record 25 of Set 5 | dunedin
# Processing Record 26 of Set 5 | kutum
# Processing Record 27 of Set 5 | tiksi
# Processing Record 28 of Set 5 | panguna
# Processing Record 29 of Set 5 | hawera
# Processing Record 30 of Set 5 | brewster
# Processing Record 31 of Set 5 | jega
# Processing Record 32 of Set 5 | tazovskiy
# Processing Record 33 of Set 5 | nemuro
# Processing Record 34 of Set 5 | esperance
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | chabahar
# Processing Record 37 of Set 5 | camiri
# Processing Record 38 of Set 5 | pareora
# Processing Record 39 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 40 of Set 5 | hamilton
# Processing Record 41 of Set 5 | komsomolskiy
# Processing Record 42 of Set 5 | ozernovskiy
# Processing Record 43 of Set 5 | moralillo
# Processing Record 44 of Set 5 | preobrazheniye
# Processing Record 45 of Set 5 | riyadh
# Processing Record 46 of Set 5 | nisia floresta
# Processing Record 47 of Set 5 | khilok
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | los banos
# Processing Record 50 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 1 of Set 6 | iwaki
# Processing Record 2 of Set 6 | sorland
# Processing Record 3 of Set 6 | soledad
# Processing Record 4 of Set 6 | aswan
# Processing Record 5 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 6 | san jose de gracia
# Processing Record 7 of Set 6 | zhigansk
# Processing Record 8 of Set 6 | iqaluit
# Processing Record 9 of Set 6 | pedernales
# Processing Record 10 of Set 6 | auki
# Processing Record 11 of Set 6 | fort nelson
# Processing Record 12 of Set 6 | krasnoselkup
# Processing Record 13 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 14 of Set 6 | sol-iletsk
# Processing Record 15 of Set 6 | codrington
# Processing Record 16 of Set 6 | vulcan
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | olavarria
# Processing Record 19 of Set 6 | bandarbeyla
# Processing Record 20 of Set 6 | tadine
# Processing Record 21 of Set 6 | boguchany
# Processing Record 22 of Set 6 | roald
# Processing Record 23 of Set 6 | tarrafal
# Processing Record 24 of Set 6 | umea
# Processing Record 25 of Set 6 | kendari
# Processing Record 26 of Set 6 | najran
# Processing Record 27 of Set 6 | meadow lake
# Processing Record 28 of Set 6 | tuscaloosa
# Processing Record 29 of Set 6 | katsuura
# Processing Record 30 of Set 6 | abalak
# Processing Record 31 of Set 6 | lompoc
# Processing Record 32 of Set 6 | lorengau
# Processing Record 33 of Set 6 | waingapu
# Processing Record 34 of Set 6 | east london
# Processing Record 35 of Set 6 | nacala
# Processing Record 36 of Set 6 | zavodoukovsk
# Processing Record 37 of Set 6 | viedma
# Processing Record 38 of Set 6 | banda aceh
# Processing Record 39 of Set 6 | sambava
# Processing Record 40 of Set 6 | leningradskiy
# Processing Record 41 of Set 6 | baherden
# Processing Record 42 of Set 6 | dingle
# Processing Record 43 of Set 6 | muzhi
# Processing Record 44 of Set 6 | kijang
# Processing Record 45 of Set 6 | narasannapeta
# Processing Record 46 of Set 6 | beisfjord
# Processing Record 47 of Set 6 | carutapera
# Processing Record 48 of Set 6 | san policarpo
# Processing Record 49 of Set 6 | sioux lookout
# Processing Record 50 of Set 6 | castro
# Processing Record 1 of Set 7 | segezha
# Processing Record 2 of Set 7 | billings
# Processing Record 3 of Set 7 | acapulco
# Processing Record 4 of Set 7 | majene
# Processing Record 5 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 7 | mezen
# Processing Record 7 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 7 | urengoy
# Processing Record 9 of Set 7 | luena
# Processing Record 10 of Set 7 | mount isa
# Processing Record 11 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 12 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 13 of Set 7 | conceicao do araguaia
# Processing Record 14 of Set 7 | san quintin
# Processing Record 15 of Set 7 | byron bay
# Processing Record 16 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 17 of Set 7 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 7 | rapid valley
# Processing Record 19 of Set 7 | callaway
# Processing Record 20 of Set 7 | namatanai
# Processing Record 21 of Set 7 | mana
# Processing Record 22 of Set 7 | tuktoyaktuk
# Processing Record 23 of Set 7 | loreto
# Processing Record 24 of Set 7 | xuddur
# Processing Record 25 of Set 7 | kalangala
# Processing Record 26 of Set 7 | suslonger
# Processing Record 27 of Set 7 | avera
# Processing Record 28 of Set 7 | erzincan
# Processing Record 29 of Set 7 | mallasamudram
# Processing Record 30 of Set 7 | atar
# Processing Record 31 of Set 7 | sunrise manor
# Processing Record 32 of Set 7 | severo-kurilsk
# Processing Record 33 of Set 7 | ponta delgada
# Processing Record 34 of Set 7 | alta gracia
# Processing Record 35 of Set 7 | koshurnikovo
# Processing Record 36 of Set 7 | holme
# Processing Record 37 of Set 7 | pevek
# Processing Record 38 of Set 7 | tuatapere
# Processing Record 39 of Set 7 | dinguiraye
# Processing Record 40 of Set 7 | olive branch
# Processing Record 41 of Set 7 | chumikan
# Processing Record 42 of Set 7 | vila franca do campo
# Processing Record 43 of Set 7 | te anau
# Processing Record 44 of Set 7 | belaya gora
# Processing Record 45 of Set 7 | cabo san lucas
# Processing Record 46 of Set 7 | ukiah
# Processing Record 47 of Set 7 | arlit
# Processing Record 48 of Set 7 | frutigen
# Processing Record 49 of Set 7 | kloulklubed
# Processing Record 50 of Set 7 | khani
# Processing Record 1 of Set 8 | burica
# City not found. Skipping...
# Processing Record 2 of Set 8 | port-gentil
# Processing Record 3 of Set 8 | sai buri
# Processing Record 4 of Set 8 | chittur
# Processing Record 5 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 6 of Set 8 | torit
# Processing Record 7 of Set 8 | bhind
# Processing Record 8 of Set 8 | krivosheino
# Processing Record 9 of Set 8 | niltepec
# Processing Record 10 of Set 8 | evensk
# Processing Record 11 of Set 8 | jacareacanga
# Processing Record 12 of Set 8 | kavaratti
# Processing Record 13 of Set 8 | koungou
# Processing Record 14 of Set 8 | ixtapa
# Processing Record 15 of Set 8 | vreed en hoop
# City not found. Skipping...
# Processing Record 16 of Set 8 | parit buntar
# Processing Record 17 of Set 8 | tvoroyri
# Processing Record 18 of Set 8 | muktagachha
# City not found. Skipping...
# Processing Record 19 of Set 8 | anadyr
# Processing Record 20 of Set 8 | coahuayana
# Processing Record 21 of Set 8 | broome
# Processing Record 22 of Set 8 | kalmar
# Processing Record 23 of Set 8 | minas de barroteran
# Processing Record 24 of Set 8 | grindavik
# Processing Record 25 of Set 8 | dudinka
# Processing Record 26 of Set 8 | mbocayaty
# Processing Record 27 of Set 8 | filingue
# Processing Record 28 of Set 8 | lavrentiya
# Processing Record 29 of Set 8 | makat
# Processing Record 30 of Set 8 | helong
# Processing Record 31 of Set 8 | sechura
# Processing Record 32 of Set 8 | matane
# Processing Record 33 of Set 8 | jiazi
# Processing Record 34 of Set 8 | tahta
# Processing Record 35 of Set 8 | maraba
# Processing Record 36 of Set 8 | acarau
# Processing Record 37 of Set 8 | baker city
# Processing Record 38 of Set 8 | muscat
# Processing Record 39 of Set 8 | serebryanyy bor
# Processing Record 40 of Set 8 | yar-sale
# Processing Record 41 of Set 8 | labuan
# Processing Record 42 of Set 8 | mangan
# Processing Record 43 of Set 8 | ancud
# Processing Record 44 of Set 8 | madridejos
# Processing Record 45 of Set 8 | mount gambier
# Processing Record 46 of Set 8 | shirokiy
# Processing Record 47 of Set 8 | marsabit
# Processing Record 48 of Set 8 | naraina
# Processing Record 49 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 8 | coquimbo
# Processing Record 1 of Set 9 | pinyug
# Processing Record 2 of Set 9 | leh
# Processing Record 3 of Set 9 | rohru
# Processing Record 4 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 5 of Set 9 | matagami
# Processing Record 6 of Set 9 | corinto
# Processing Record 7 of Set 9 | guanay
# Processing Record 8 of Set 9 | la ronge
# Processing Record 9 of Set 9 | imeni poliny osipenko
# Processing Record 10 of Set 9 | touros
# Processing Record 11 of Set 9 | trogir
# Processing Record 12 of Set 9 | zhanakorgan
# Processing Record 13 of Set 9 | saint george
# Processing Record 14 of Set 9 | hirara
# Processing Record 15 of Set 9 | shirvan
# Processing Record 16 of Set 9 | apatou
# Processing Record 17 of Set 9 | traiguen
# Processing Record 18 of Set 9 | wrexham
# Processing Record 19 of Set 9 | strelna
# Processing Record 20 of Set 9 | clyde river
# Processing Record 21 of Set 9 | tatarskaya kargala
# Processing Record 22 of Set 9 | den helder
# Processing Record 23 of Set 9 | haines junction
# Processing Record 24 of Set 9 | ilebo
# Processing Record 25 of Set 9 | jinchang
# Processing Record 26 of Set 9 | kaeo
# Processing Record 27 of Set 9 | belle fourche
# Processing Record 28 of Set 9 | balakhninskiy
# Processing Record 29 of Set 9 | sawakin
# Processing Record 30 of Set 9 | kahului
# Processing Record 31 of Set 9 | narkanda
# Processing Record 32 of Set 9 | luwingu
# Processing Record 33 of Set 9 | pierre
# Processing Record 34 of Set 9 | chicama
# Processing Record 35 of Set 9 | baracoa
# Processing Record 36 of Set 9 | cockburn town
# Processing Record 37 of Set 9 | port hueneme
# Processing Record 38 of Set 9 | tres arroyos
# Processing Record 39 of Set 9 | geresk
# City not found. Skipping...
# Processing Record 40 of Set 9 | fairmont
# Processing Record 41 of Set 9 | tomatlan
# Processing Record 42 of Set 9 | wasilla
# Processing Record 43 of Set 9 | harper
# Processing Record 44 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 9 | basoko
# Processing Record 46 of Set 9 | vrangel
# Processing Record 47 of Set 9 | biak
# Processing Record 48 of Set 9 | ornskoldsvik
# Processing Record 49 of Set 9 | zabid
# Processing Record 50 of Set 9 | san pedro de macoris
# Processing Record 1 of Set 10 | pangnirtung
# Processing Record 2 of Set 10 | kalengwa
# Processing Record 3 of Set 10 | tacoronte
# Processing Record 4 of Set 10 | okhotsk
# Processing Record 5 of Set 10 | tilichiki
# Processing Record 6 of Set 10 | novyy urengoy
# Processing Record 7 of Set 10 | verkhnevilyuysk
# Processing Record 8 of Set 10 | aripuana
# Processing Record 9 of Set 10 | katsiveli
# City not found. Skipping...
# Processing Record 10 of Set 10 | levokumka
# Processing Record 11 of Set 10 | srednekolymsk
# Processing Record 12 of Set 10 | pangody
# Processing Record 13 of Set 10 | bubaque
# Processing Record 14 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 10 | ijaki
# City not found. Skipping...
# Processing Record 16 of Set 10 | quatre cocos
# Processing Record 17 of Set 10 | saint-georges
# Processing Record 18 of Set 10 | kundiawa
# Processing Record 19 of Set 10 | kiunga
# Processing Record 20 of Set 10 | ust-karsk
# Processing Record 21 of Set 10 | umm lajj
# Processing Record 22 of Set 10 | saint-joseph
# Processing Record 23 of Set 10 | namibe
# Processing Record 24 of Set 10 | abu samrah
# Processing Record 25 of Set 10 | savannah bight
# Processing Record 26 of Set 10 | krasnoborsk
# Processing Record 27 of Set 10 | misawa
# Processing Record 28 of Set 10 | bocas del toro
# Processing Record 29 of Set 10 | deputatskiy
# Processing Record 30 of Set 10 | priseaca
# Processing Record 31 of Set 10 | paka
# Processing Record 32 of Set 10 | yirol
# City not found. Skipping...
# Processing Record 33 of Set 10 | codajas
# Processing Record 34 of Set 10 | conde
# Processing Record 35 of Set 10 | nizhniy odes
# Processing Record 36 of Set 10 | djibo
# Processing Record 37 of Set 10 | kuching
# Processing Record 38 of Set 10 | derzhavinsk
# Processing Record 39 of Set 10 | manzil tamim
# City not found. Skipping...
# Processing Record 40 of Set 10 | koutiala
# Processing Record 41 of Set 10 | neiafu
# Processing Record 42 of Set 10 | barcelos
# Processing Record 43 of Set 10 | mayskiy
# Processing Record 44 of Set 10 | vikulovo
# Processing Record 45 of Set 10 | north bend
# Processing Record 46 of Set 10 | puerto carreno
# Processing Record 47 of Set 10 | boisoara
# Processing Record 48 of Set 10 | duluth
# Processing Record 49 of Set 10 | botou
# Processing Record 50 of Set 10 | norrtalje
# Processing Record 1 of Set 11 | natal
# Processing Record 2 of Set 11 | marrakesh
# Processing Record 3 of Set 11 | arona
# Processing Record 4 of Set 11 | xapuri
# Processing Record 5 of Set 11 | siocon
# Processing Record 6 of Set 11 | ndele
# Processing Record 7 of Set 11 | amahai
# Processing Record 8 of Set 11 | fairbanks
# Processing Record 9 of Set 11 | martapura
# Processing Record 10 of Set 11 | isangel
# Processing Record 11 of Set 11 | dire
# Processing Record 12 of Set 11 | kieta
# Processing Record 13 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 14 of Set 11 | asyut
# Processing Record 15 of Set 11 | orotukan
# Processing Record 16 of Set 11 | kapuskasing
# Processing Record 17 of Set 11 | kitimat
# Processing Record 18 of Set 11 | oxford
# Processing Record 19 of Set 11 | jalu
# Processing Record 20 of Set 11 | mwinilunga
# Processing Record 21 of Set 11 | tessalit
# Processing Record 22 of Set 11 | alice springs
# Processing Record 23 of Set 11 | fiumicino
# Processing Record 24 of Set 11 | juegang
# Processing Record 25 of Set 11 | vilyuysk
# Processing Record 26 of Set 11 | tisul
# Processing Record 27 of Set 11 | lazaro cardenas
# Processing Record 28 of Set 11 | jamnah
# City not found. Skipping...
# Processing Record 29 of Set 11 | taoudenni
# Processing Record 30 of Set 11 | zacualpan
# Processing Record 31 of Set 11 | snezhnogorsk
# Processing Record 32 of Set 11 | santa fe
# Processing Record 33 of Set 11 | ankazoabo
# Processing Record 34 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 11 | togur
# Processing Record 36 of Set 11 | fare
# Processing Record 37 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 38 of Set 11 | skjervoy
# Processing Record 39 of Set 11 | kasra
# City not found. Skipping...
# Processing Record 40 of Set 11 | nouadhibou
# Processing Record 41 of Set 11 | bonavista
# Processing Record 42 of Set 11 | mingaora
# Processing Record 43 of Set 11 | brigantine
# Processing Record 44 of Set 11 | debre sina
# Processing Record 45 of Set 11 | manaus
# Processing Record 46 of Set 11 | egvekinot
# Processing Record 47 of Set 11 | kalabo
# Processing Record 48 of Set 11 | uusikaupunki
# Processing Record 49 of Set 11 | ampanihy
# Processing Record 50 of Set 11 | qaqortoq
# Processing Record 1 of Set 12 | bol
# Processing Record 2 of Set 12 | lumeje
# Processing Record 3 of Set 12 | itoman
# Processing Record 4 of Set 12 | vardo
# Processing Record 5 of Set 12 | kainantu
# Processing Record 6 of Set 12 | bejar
# Processing Record 7 of Set 12 | yertarskiy
# Processing Record 8 of Set 12 | sorong
# Processing Record 9 of Set 12 | masallatah
# Processing Record 10 of Set 12 | nador
# Processing Record 11 of Set 12 | porto walter
# Processing Record 12 of Set 12 | siirt
# Processing Record 13 of Set 12 | xicotencatl
# Processing Record 14 of Set 12 | caravelas
# Processing Record 15 of Set 12 | zelenogorskiy
# Processing Record 16 of Set 12 | princeton
# Processing Record 17 of Set 12 | jaen
# Processing Record 18 of Set 12 | opelousas
# Processing Record 19 of Set 12 | hoquiam
# Processing Record 20 of Set 12 | henties bay
# Processing Record 21 of Set 12 | sorada
# Processing Record 22 of Set 12 | wajir
# Processing Record 23 of Set 12 | olinda
# Processing Record 24 of Set 12 | rincon
# Processing Record 25 of Set 12 | baculin
# Processing Record 26 of Set 12 | sham churasi
# Processing Record 27 of Set 12 | oum hadjer
# Processing Record 28 of Set 12 | beringovskiy
# Processing Record 29 of Set 12 | ajdabiya
# Processing Record 30 of Set 12 | aleksandrov gay
# Processing Record 31 of Set 12 | wuwei
# Processing Record 32 of Set 12 | necochea
# Processing Record 33 of Set 12 | batemans bay
# Processing Record 34 of Set 12 | bilma
# Processing Record 35 of Set 12 | severo-yeniseyskiy
# Processing Record 36 of Set 12 | labuhan
# Processing Record 37 of Set 12 | nanae
# Processing Record 38 of Set 12 | hobyo
# Processing Record 39 of Set 12 | fukue
# Processing Record 40 of Set 12 | sherlovaya gora
# Processing Record 41 of Set 12 | dali
# Processing Record 42 of Set 12 | erenhot
# Processing Record 43 of Set 12 | sitka
# Processing Record 44 of Set 12 | kyra
# Processing Record 45 of Set 12 | asau
# Processing Record 46 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 47 of Set 12 | bathsheba
# Processing Record 48 of Set 12 | tolaga bay
# Processing Record 49 of Set 12 | honningsvag
# Processing Record 50 of Set 12 | kalikapur
# Processing Record 1 of Set 13 | kolyvan
# Processing Record 2 of Set 13 | eydhafushi
# Processing Record 3 of Set 13 | diplahan
# Processing Record 4 of Set 13 | wajima
# Processing Record 5 of Set 13 | fernandez
# Processing Record 6 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 7 of Set 13 | ust-nera
# Processing Record 8 of Set 13 | teguise
# Processing Record 9 of Set 13 | tabou
# Processing Record 10 of Set 13 | mingshui
# Processing Record 11 of Set 13 | arrifes
# Processing Record 12 of Set 13 | san diego
# Processing Record 13 of Set 13 | excelsior springs
# Processing Record 14 of Set 13 | kismayo
# Processing Record 15 of Set 13 | gazli
# Processing Record 16 of Set 13 | bago
# Processing Record 17 of Set 13 | berlevag
# Processing Record 18 of Set 13 | babu
# Processing Record 19 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 13 | vangaindrano
# Processing Record 21 of Set 13 | jasper
# Processing Record 22 of Set 13 | kedrovyy
# Processing Record 23 of Set 13 | nogales
# Processing Record 24 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 25 of Set 13 | verdalsora
# City not found. Skipping...
# Processing Record 26 of Set 13 | simbahan
# Processing Record 27 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 13 | tabuk
# Processing Record 29 of Set 13 | nakhon thai
# Processing Record 30 of Set 13 | adrar
# Processing Record 31 of Set 13 | nichinan
# Processing Record 32 of Set 13 | hoima
# Processing Record 33 of Set 13 | svetlogorsk
# Processing Record 34 of Set 13 | mayo
# Processing Record 35 of Set 13 | kenai
# Processing Record 36 of Set 13 | snasa
# Processing Record 37 of Set 13 | taltal
# Processing Record 38 of Set 13 | maues
# Processing Record 39 of Set 13 | sarai naurang
# Processing Record 40 of Set 13 | baoqing
# Processing Record 41 of Set 13 | havelock
# Processing Record 42 of Set 13 | isla mujeres
# Processing Record 43 of Set 13 | taitung
# Processing Record 44 of Set 13 | kattivakkam
# Processing Record 45 of Set 13 | san jose
# Processing Record 46 of Set 13 | mongoumba
# Processing Record 47 of Set 13 | ginda
# Processing Record 48 of Set 13 | amalapuram
# Processing Record 49 of Set 13 | maragogi
# Processing Record 50 of Set 13 | sao joao da barra
# Processing Record 1 of Set 14 | guerrero negro
# Processing Record 2 of Set 14 | madang
# Processing Record 3 of Set 14 | grand gaube
# Processing Record 4 of Set 14 | pacific grove
# Processing Record 5 of Set 14 | wanning
# Processing Record 6 of Set 14 | walvis bay
# Processing Record 7 of Set 14 | anloga
# Processing Record 8 of Set 14 | kandrian
# Processing Record 9 of Set 14 | aromashevo
# Processing Record 10 of Set 14 | kushiro
# Processing Record 11 of Set 14 | blagoyevo
# Processing Record 12 of Set 14 | fallon
# Processing Record 13 of Set 14 | gushikawa
# Processing Record 14 of Set 14 | san juan
# Processing Record 15 of Set 14 | sabya
# Processing Record 16 of Set 14 | chaohu
# Processing Record 17 of Set 14 | tautira
# Processing Record 18 of Set 14 | port macquarie
# Processing Record 19 of Set 14 | sao francisco
# Processing Record 20 of Set 14 | marabba
# Processing Record 21 of Set 14 | kushima
# Processing Record 22 of Set 14 | nyurba
# Processing Record 23 of Set 14 | poum
# Processing Record 24 of Set 14 | hay river
# Processing Record 25 of Set 14 | colac
# Processing Record 26 of Set 14 | kamenka
# Processing Record 27 of Set 14 | liverpool
# Processing Record 28 of Set 14 | kang
# Processing Record 29 of Set 14 | dhidhdhoo
# Processing Record 30 of Set 14 | cleethorpes
# Processing Record 31 of Set 14 | wewak
# Processing Record 32 of Set 14 | jorpeland
# Processing Record 33 of Set 14 | kincardine
# Processing Record 34 of Set 14 | verkhniy baskunchak
# Processing Record 35 of Set 14 | synya
# Processing Record 36 of Set 14 | kurchum
# Processing Record 37 of Set 14 | ardakan
# Processing Record 38 of Set 14 | nurlat
# Processing Record 39 of Set 14 | obidos
# Processing Record 40 of Set 14 | chiang mai
# Processing Record 41 of Set 14 | ostrovskoye
# Processing Record 42 of Set 14 | mayfield
# Processing Record 43 of Set 14 | dulce nombre de culmi
# Processing Record 44 of Set 14 | peniche
# Processing Record 45 of Set 14 | grand-santi
# Processing Record 46 of Set 14 | znamenskoye
# Processing Record 47 of Set 14 | hauterive
# Processing Record 48 of Set 14 | fengrun
# Processing Record 49 of Set 14 | orlik
# Processing Record 50 of Set 14 | rosario oeste
# Processing Record 1 of Set 15 | beyneu
# Processing Record 2 of Set 15 | milverton
# Processing Record 3 of Set 15 | izumo
# Processing Record 4 of Set 15 | gornopravdinsk
# Processing Record 5 of Set 15 | kununurra
# Processing Record 6 of Set 15 | les cayes
# Processing Record 7 of Set 15 | pangkalanbuun
# Processing Record 8 of Set 15 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 15 | huilong
# Processing Record 10 of Set 15 | sola
# Processing Record 11 of Set 15 | dandong
# Processing Record 12 of Set 15 | kawambwa
# Processing Record 13 of Set 15 | gigmoto
# Processing Record 14 of Set 15 | shingu
# Processing Record 15 of Set 15 | korzhevskiy
# Processing Record 16 of Set 15 | polovinnoye
# Processing Record 17 of Set 15 | itarema
# Processing Record 18 of Set 15 | santa rosa
# Processing Record 19 of Set 15 | black river
# Processing Record 20 of Set 15 | penzance
# Processing Record 21 of Set 15 | sinop
# Processing Record 22 of Set 15 | bulgan
# Processing Record 23 of Set 15 | uruacu
# Processing Record 24 of Set 15 | kapoeta
# Processing Record 25 of Set 15 | lichinga
# Processing Record 26 of Set 15 | honghu
# Processing Record 27 of Set 15 | port blair
# Processing Record 28 of Set 15 | vostok
# Processing Record 29 of Set 15 | kindu
# Processing Record 30 of Set 15 | port lincoln
# Processing Record 31 of Set 15 | lydenburg
# Processing Record 32 of Set 15 | yumen
# Processing Record 33 of Set 15 | wuchang
# Processing Record 34 of Set 15 | goderich
# Processing Record 35 of Set 15 | west richland
# Processing Record 36 of Set 15 | ust-koksa
# Processing Record 37 of Set 15 | sinnamary
# Processing Record 38 of Set 15 | ambulu
# Processing Record 39 of Set 15 | eston
# Processing Record 40 of Set 15 | jiexiu
# Processing Record 41 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 42 of Set 15 | zhanatas
# City not found. Skipping...
# Processing Record 43 of Set 15 | barra patuca
# Processing Record 44 of Set 15 | svobodnyy
# Processing Record 45 of Set 15 | calabozo
# Processing Record 46 of Set 15 | labelle
# Processing Record 47 of Set 15 | oriximina
# Processing Record 48 of Set 15 | sharan
# Processing Record 49 of Set 15 | chardara
# Processing Record 50 of Set 15 | bethanien
# Processing Record 1 of Set 16 | barra do garcas
# Processing Record 2 of Set 16 | ust-kuyga
# Processing Record 3 of Set 16 | lodja
# Processing Record 4 of Set 16 | ialibu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the city count to confirm sufficient count.
len(city_data)
# Out:
# 700

# %%
# 7. Add the data to a new DataFrame.
#Before exporting your new DataFrame as a CSV file, take a moment to confirm that all information are present.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Bud      US  39.4470  -86.1758     71.62        97         100
# 1         Bouca      CF   6.5105   18.2733     69.58        99         100
# 2       Mataura      NZ -46.1927  168.8643     55.47        62          99
# 3  Puerto Ayora      EC  -0.7393  -90.3518     68.56        89          74
# 4        Hegang      CN  47.4000  130.3667     65.98        91         100
# 5    Georgetown      MY   5.4112  100.3354     84.13        93          20
# 6      Cherskiy      RU  68.7500  161.3000     52.61        40          76
# 7    Butaritari      KI   3.0707  172.7902     82.36        73          12
# 8   Port Alfred      ZA -33.5906   26.8910     66.11        39           2
# 9        Padang      ID  -0.9492  100.3543     77.05        55          11
#
#    Wind Speed Weather description
# 0        5.61     overcast clouds
# 1        4.09     overcast clouds
# 2       13.60          light rain
# 3        5.01       broken clouds
# 4        3.85     overcast clouds
# 5        3.44                haze
# 6       18.79       broken clouds
# 7       13.71          few clouds
# 8       10.02           clear sky
# 9        1.03          few clouds

# %%
# 8. Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index_label="City_ID")
